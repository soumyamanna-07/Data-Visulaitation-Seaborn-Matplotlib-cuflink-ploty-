# %%
# ploty : 
#It's not too much important , it use for desigh basically and aslo more in financial visulaizaton  , it shows plot more attractive visulaization

# %%
# cufflinks : 
#it connect ploty with pandas to create graph

# %%
# It is not pre install in anaconda ,so you need to  install

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.1 MB 611.8 kB/s eta 0:00:14
#    -- ------------------------------------- 0.5/9.1 MB 611.8 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/9.1 MB 661.5 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/9.1 MB 661.5 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.0/9.1 MB 624.4 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.0/9.1 MB 624.4 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.0/9.1 MB 624.4 kB/s eta 0:00:13
# ...

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 889.9 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 889.9 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.5 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.14.exe and pip3.exe are installed in 'C:\Users\SOUMYA MANNA\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
# ...

# %%
# !pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68889 sha256=745c59c1166e1cb66c4e24a53092801396e919004dc5bcee8349206e8106b15e
#   Stored in directory: c:\users\soumya manna\appdata\local\pip\cache\wheels\e4\0d\21\3611484024347032ee330271868478a2c28877581eb01f9b79
# Successfully built cufflinks
# ...
#
#    -------------------- ------------------- 1/2 [cufflinks]
#    ---------------------------------------- 2/2 [cufflinks]
#
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# ...

# %%
pip install -- upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline  import iplot        # import all libraly

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].iplot()               # Create a line graph of total_bill
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tips['total_bill'].iplot()               # Create a line graph of total_bill
#
# File ~\AppData\Roaming\Python\Python314\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
# ...

# %%
# !pip install --upgrade plotly cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
